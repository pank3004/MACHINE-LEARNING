# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X, y=make_regression(n_samples=1000, n_features=10,noise=10, random_state=1)

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=1)

# %%
regressor=GradientBoostingRegressor()
regressor.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred=regressor.predict(X_test)

print("Current model performace")
print(f"r2 score: {r2_score(y_test, y_pred)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE: {mean_squared_error(y_test, y_pred)}")
# Out:
# Current model performace
# r2 score: 0.9091317801650575
# MAE: 40.59521530440614
# MSE: 2922.147434463169

# %%
# hyper parameter tuning: 
from sklearn.model_selection import GridSearchCV
param_grid={
    'n_estimators': [50,100,200],
    'learning_rate': [0.01, 0.1,0.5, 1.0, 1.5],
     # 'max_depth': [3,4,5],
    # 'subsample': [0.8, 0.9, 1.0],
    # 'min_samples_split': [2,5,10],
    # 'min_samples_leaf': [1,2,4]
}

# %%
gbr=GradientBoostingRegressor()

# %%
grid_search=GridSearchCV(estimator=gbr, param_grid=param_grid,cv=5, verbose=3)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=50;, score=0.316 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=50;, score=0.304 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=50;, score=0.350 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=50;, score=0.324 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, n_estimators=50;, score=0.342 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.507 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.496 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.529 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.512 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.538 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.691 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.685 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.717 total time=   0.7s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.699 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.723 total time=   0.8s
# [CV 1/5] END learning_rate=0.1, n_estimators=50;, score=0.859 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=50;, score=0.854 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, n_estimators=50;, score=0.878 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=50;, score=0.871 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=50;, score=0.879 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.909 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.907 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.926 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.918 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.927 total time=   0.6s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.924 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.943 total time=   0.8s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.936 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.942 total time=   0.7s
# [CV 1/5] END learning_rate=0.5, n_estimators=50;, score=0.848 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=50;, score=0.855 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, n_estimators=50;, score=0.928 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, n_estimators=50;, score=0.869 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=50;, score=0.885 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, n_estimators=100;, score=0.856 total time=   0.4s
# [CV 2/5] END learning_rate=0.5, n_estimators=100;, score=0.862 total time=   0.4s
# [CV 3/5] END learning_rate=0.5, n_estimators=100;, score=0.929 total time=   0.3s
# [CV 4/5] END learning_rate=0.5, n_estimators=100;, score=0.873 total time=   0.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=100;, score=0.886 total time=   0.3s
# [CV 1/5] END learning_rate=0.5, n_estimators=200;, score=0.853 total time=   0.8s
# [CV 2/5] END learning_rate=0.5, n_estimators=200;, score=0.859 total time=   0.7s
# [CV 3/5] END learning_rate=0.5, n_estimators=200;, score=0.928 total time=   0.8s
# [CV 4/5] END learning_rate=0.5, n_estimators=200;, score=0.872 total time=   0.7s
# [CV 5/5] END learning_rate=0.5, n_estimators=200;, score=0.885 total time=   0.8s
# [CV 1/5] END learning_rate=1.0, n_estimators=50;, score=0.612 total time=   0.1s
# [CV 2/5] END learning_rate=1.0, n_estimators=50;, score=0.636 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=50;, score=0.734 total time=   0.1s
# [CV 4/5] END learning_rate=1.0, n_estimators=50;, score=0.759 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, n_estimators=50;, score=0.777 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=0.602 total time=   0.3s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=0.652 total time=   0.3s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=0.736 total time=   0.3s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=0.754 total time=   0.3s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=0.775 total time=   0.3s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=0.625 total time=   0.7s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=0.638 total time=   0.9s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=0.746 total time=   0.8s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=0.754 total time=   0.7s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=0.772 total time=   0.9s
# [CV 1/5] END learning_rate=1.5, n_estimators=50;, score=0.090 total time=   0.1s
# [CV 2/5] END learning_rate=1.5, n_estimators=50;, score=0.159 total time=   0.1s
# [CV 3/5] END learning_rate=1.5, n_estimators=50;, score=0.152 total time=   0.1s
# [CV 4/5] END learning_rate=1.5, n_estimators=50;, score=0.069 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, n_estimators=50;, score=0.179 total time=   0.1s
# [CV 1/5] END learning_rate=1.5, n_estimators=100;, score=-0.046 total time=   0.3s
# [CV 2/5] END learning_rate=1.5, n_estimators=100;, score=0.056 total time=   0.3s
# [CV 3/5] END learning_rate=1.5, n_estimators=100;, score=0.079 total time=   0.3s
# [CV 4/5] END learning_rate=1.5, n_estimators=100;, score=0.095 total time=   0.4s
# [CV 5/5] END learning_rate=1.5, n_estimators=100;, score=0.166 total time=   0.4s
# [CV 1/5] END learning_rate=1.5, n_estimators=200;, score=-0.024 total time=   0.7s
# [CV 2/5] END learning_rate=1.5, n_estimators=200;, score=0.013 total time=   0.7s
# [CV 3/5] END learning_rate=1.5, n_estimators=200;, score=0.060 total time=   0.7s
# [CV 4/5] END learning_rate=1.5, n_estimators=200;, score=0.101 total time=   0.7s
# [CV 5/5] END learning_rate=1.5, n_estimators=200;, score=0.163 total time=   0.7s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 200}

# %%
grid_search.best_score_
# Out:
# 0.9342880054868784

# %%
best_model=grid_search.best_estimator_
y_pred=best_model.predict(X_test)

print("Current model performace")
print(f"r2 score: {r2_score(y_test, y_pred)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE: {mean_squared_error(y_test, y_pred)}")
# Out:
# Current model performace
# r2 score: 0.9336160437064901
# MAE: 34.986551605238326
# MSE: 2134.780541810509

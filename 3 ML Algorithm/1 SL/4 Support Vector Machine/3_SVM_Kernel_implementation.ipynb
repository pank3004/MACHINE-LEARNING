# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
x=np.linspace(-6.0, 6.0, 100)

# %%
x
# Out:
# array([-6.        , -5.87878788, -5.75757576, -5.63636364, -5.51515152,
#        -5.39393939, -5.27272727, -5.15151515, -5.03030303, -4.90909091,
#        -4.78787879, -4.66666667, -4.54545455, -4.42424242, -4.3030303 ,
#        -4.18181818, -4.06060606, -3.93939394, -3.81818182, -3.6969697 ,
#        -3.57575758, -3.45454545, -3.33333333, -3.21212121, -3.09090909,
#        -2.96969697, -2.84848485, -2.72727273, -2.60606061, -2.48484848,
#        -2.36363636, -2.24242424, -2.12121212, -2.        , -1.87878788,
#        -1.75757576, -1.63636364, -1.51515152, -1.39393939, -1.27272727,
#        -1.15151515, -1.03030303, -0.90909091, -0.78787879, -0.66666667,
#        -0.54545455, -0.42424242, -0.3030303 , -0.18181818, -0.06060606,
#         0.06060606,  0.18181818,  0.3030303 ,  0.42424242,  0.54545455,
#         0.66666667,  0.78787879,  0.90909091,  1.03030303,  1.15151515,
#         1.27272727,  1.39393939,  1.51515152,  1.63636364,  1.75757576,
# ...

# %%
y=np.sqrt(10**2-x**2)

# %%
y
# Out:
# array([8.        , 8.08949029, 8.17620458, 8.26023032, 8.34164874,
#        8.42053548, 8.49696105, 8.57099129, 8.64268774, 8.71210804,
#        8.77930616, 8.84433277, 8.90723543, 8.96805882, 9.02684498,
#        9.08363345, 9.13846149, 9.19136417, 9.24237457, 9.29152383,
#        9.33884135, 9.38435484, 9.42809042, 9.47007272, 9.51032497,
#        9.54886904, 9.58572554, 9.62091386, 9.65445224, 9.68635783,
#        9.7166467 , 9.74533394, 9.77243363, 9.79795897, 9.82192222,
#        9.84433479, 9.86520725, 9.88454935, 9.90237007, 9.9186776 ,
#        9.93347939, 9.94678218, 9.95859195, 9.96891403, 9.97775303,
#        9.98511289, 9.99099687, 9.99540758, 9.99834697, 9.99981634,
#        9.99981634, 9.99834697, 9.99540758, 9.99099687, 9.98511289,
#        9.97775303, 9.96891403, 9.95859195, 9.94678218, 9.93347939,
#        9.9186776 , 9.90237007, 9.88454935, 9.86520725, 9.84433479,
#        9.82192222, 9.79795897, 9.77243363, 9.74533394, 9.7166467 ,
# ...

# %%
y=np.hstack([y,-y])

# %%
print(y)
# Out:
# [ 8.          8.08949029  8.17620458  8.26023032  8.34164874  8.42053548
#   8.49696105  8.57099129  8.64268774  8.71210804  8.77930616  8.84433277
#   8.90723543  8.96805882  9.02684498  9.08363345  9.13846149  9.19136417
#   9.24237457  9.29152383  9.33884135  9.38435484  9.42809042  9.47007272
#   9.51032497  9.54886904  9.58572554  9.62091386  9.65445224  9.68635783
#   9.7166467   9.74533394  9.77243363  9.79795897  9.82192222  9.84433479
#   9.86520725  9.88454935  9.90237007  9.9186776   9.93347939  9.94678218
#   9.95859195  9.96891403  9.97775303  9.98511289  9.99099687  9.99540758
#   9.99834697  9.99981634  9.99981634  9.99834697  9.99540758  9.99099687
#   9.98511289  9.97775303  9.96891403  9.95859195  9.94678218  9.93347939
#   9.9186776   9.90237007  9.88454935  9.86520725  9.84433479  9.82192222
#   9.79795897  9.77243363  9.74533394  9.7166467   9.68635783  9.65445224
#   9.62091386  9.58572554  9.54886904  9.51032497  9.47007272  9.42809042
# ...

# %%
len(y)
# Out:
# 200

# %%
x=np.hstack([x,-x])

# %%
x
# Out:
# array([-6.        , -5.87878788, -5.75757576, -5.63636364, -5.51515152,
#        -5.39393939, -5.27272727, -5.15151515, -5.03030303, -4.90909091,
#        -4.78787879, -4.66666667, -4.54545455, -4.42424242, -4.3030303 ,
#        -4.18181818, -4.06060606, -3.93939394, -3.81818182, -3.6969697 ,
#        -3.57575758, -3.45454545, -3.33333333, -3.21212121, -3.09090909,
#        -2.96969697, -2.84848485, -2.72727273, -2.60606061, -2.48484848,
#        -2.36363636, -2.24242424, -2.12121212, -2.        , -1.87878788,
#        -1.75757576, -1.63636364, -1.51515152, -1.39393939, -1.27272727,
#        -1.15151515, -1.03030303, -0.90909091, -0.78787879, -0.66666667,
#        -0.54545455, -0.42424242, -0.3030303 , -0.18181818, -0.06060606,
#         0.06060606,  0.18181818,  0.3030303 ,  0.42424242,  0.54545455,
#         0.66666667,  0.78787879,  0.90909091,  1.03030303,  1.15151515,
#         1.27272727,  1.39393939,  1.51515152,  1.63636364,  1.75757576,
# ...

# %%
x1=np.linspace(-6.0, 6.0, 100)
y1=np.sqrt(4**2-x1**2)
y1=np.hstack([y1,-y1])
x1=np.hstack([x1,-x1])

# %%
plt.scatter(y,x)
plt.scatter(y1,x1)

# %%
df1=pd.DataFrame(np.vstack([y,x]).T, columns=['X1', 'X2'])
df1['Y']=0

df2=pd.DataFrame(np.vstack([y1,x1]).T, columns=['X1', 'X2'])
df2['Y']=1

# %%
df1
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 195 -8.341649 -5.515152  0
# 196 -8.260230 -5.636364  0
# 197 -8.176205 -5.757576  0
# 198 -8.089490 -5.878788  0
# 199 -8.000000 -6.000000  0
#
# [200 rows x 3 columns]

# %%
df2
# Out:
#      X1        X2  Y
# 0   NaN -6.000000  1
# 1   NaN -5.878788  1
# 2   NaN -5.757576  1
# 3   NaN -5.636364  1
# 4   NaN -5.515152  1
# ..   ..       ... ..
# 195 NaN -5.515152  1
# 196 NaN -5.636364  1
# 197 NaN -5.757576  1
# 198 NaN -5.878788  1
# 199 NaN -6.000000  1
#
# [200 rows x 3 columns]

# %%
df=pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 395       NaN -5.515152  1
# 396       NaN -5.636364  1
# 397       NaN -5.757576  1
# 398       NaN -5.878788  1
# 399       NaN -6.000000  1
#
# [400 rows x 3 columns]

# %%
df.head()
# Out:
#          X1        X2  Y
# 0  8.000000 -6.000000  0
# 1  8.089490 -5.878788  0
# 2  8.176205 -5.757576  0
# 3  8.260230 -5.636364  0
# 4  8.341649 -5.515152  0

# %%
dff=df.copy()

# %%
dff.isna().sum()
# Out:
# X1    68
# X2     0
# Y      0
# dtype: int64

# %%
dff=dff.dropna()

# %%
dff
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 378 -2.016461 -3.454545  1
# 379 -1.792751 -3.575758  1
# 380 -1.527225 -3.696970  1
# 381 -1.192262 -3.818182  1
# 382 -0.693668 -3.939394  1
#
# [332 rows x 3 columns]

# %%
dff
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 378 -2.016461 -3.454545  1
# 379 -1.792751 -3.575758  1
# 380 -1.527225 -3.696970  1
# 381 -1.192262 -3.818182  1
# 382 -0.693668 -3.939394  1
#
# [332 rows x 3 columns]

# %%
dff['X1sq']=dff['X1']**2
dff['X2sq']=dff['X2']**2
dff['X1X2']=dff['X1']*dff['X2']

# %%
dff
# Out:
#            X1        X2  Y       X1sq       X2sq       X1X2
# 0    8.000000 -6.000000  0  64.000000  36.000000 -48.000000
# 1    8.089490 -5.878788  0  65.439853  34.560147 -47.556397
# 2    8.176205 -5.757576  0  66.850321  33.149679 -47.075117
# 3    8.260230 -5.636364  0  68.231405  31.768595 -46.557662
# 4    8.341649 -5.515152  0  69.583104  30.416896 -46.005457
# ..        ...       ... ..        ...        ...        ...
# 378 -2.016461 -3.454545  1   4.066116  11.933884   6.965957
# 379 -1.792751 -3.575758  1   3.213958  12.786042   6.410445
# 380 -1.527225 -3.696970  1   2.332415  13.667585   5.646103
# 381 -1.192262 -3.818182  1   1.421488  14.578512   4.552271
# 382 -0.693668 -3.939394  1   0.481175  15.518825   2.732632
#
# [332 rows x 6 columns]

# %%
X=dff[['X1sq', 'X2sq', 'X1X2']]
y=dff['Y']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.30, random_state=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((232, 3), (100, 3))

# %%
X_train
# Out:
#           X1sq       X2sq       X1X2
# 365  12.470156   3.529844   6.634584
# 17   84.481175  15.518825 -36.208404
# 267  11.500459   4.499541   7.193524
# 235  12.910927   3.089073  -6.315282
# 88   78.222222  21.777778  41.273553
# ..         ...        ...        ...
# 220   3.213958  12.786042  -6.410445
# 272   8.561983   7.438017   7.980236
# 72   92.561983   7.438017  26.238856
# 252  15.908173   0.091827   1.208638
# 37   97.704316   2.295684 -14.976590
#
# [232 rows x 3 columns]

# %%
X_test
# Out:
#           X1sq       X2sq       X1X2
# 59   98.674013   1.325987  11.438552
# 319   2.332415  13.667585  -5.646103
# 180  86.332415  13.667585  34.350482
# 192  73.461892  26.538108  44.153591
# 335  12.910927   3.089073  -6.315282
# ..         ...        ...        ...
# 39   98.380165   1.619835 -12.623771
# 117  84.481175  15.518825 -36.208404
# 78   88.066116  11.933884  32.418680
# 127  92.561983   7.438017 -26.238856
# 138  98.056933   1.943067 -13.803304
#
# [100 rows x 3 columns]

# %%
import plotly.express as px

# %%
fig=px.scatter_3d(dff, x='X1sq', y='X2sq', z='X1X2', color='Y')
fig.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
cls=SVC(kernel='linear') # why linear >> we have created plymonal 
cls.fit(X_train, y_train)
y_pred=cls.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %%
# til now we did manully
# now we will be using svc kernel's

# %%
df
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 395       NaN -5.515152  1
# 396       NaN -5.636364  1
# 397       NaN -5.757576  1
# 398       NaN -5.878788  1
# 399       NaN -6.000000  1
#
# [400 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# X1    68
# X2     0
# Y      0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#            X1        X2  Y
# 0    8.000000 -6.000000  0
# 1    8.089490 -5.878788  0
# 2    8.176205 -5.757576  0
# 3    8.260230 -5.636364  0
# 4    8.341649 -5.515152  0
# ..        ...       ... ..
# 378 -2.016461 -3.454545  1
# 379 -1.792751 -3.575758  1
# 380 -1.527225 -3.696970  1
# 381 -1.192262 -3.818182  1
# 382 -0.693668 -3.939394  1
#
# [332 rows x 3 columns]

# %%
X=df[['X1', 'X2']]
y=df['Y']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.30, random_state=1)

X_train.shape, X_test.shape
# Out:
# ((232, 2), (100, 2))

# %%
X_train
# Out:
#            X1        X2
# 365 -3.531311 -1.878788
# 17   9.191364 -3.939394
# 267  3.391233  2.121212
# 235  3.593178 -1.757576
# 88   8.844333  4.666667
# ..        ...       ...
# 220  1.792751 -3.575758
# 272  2.926087  2.727273
# 72   9.620914  2.727273
# 252  3.988505  0.303030
# 37   9.884549 -1.515152
#
# [232 rows x 2 columns]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
cls=SVC(kernel='poly') 
cls.fit(X_train, y_train)
y_pred=cls.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.62

# %%
# poly kernel did'nt perform well, so we use rbf

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
cls=SVC(kernel='rbf') 
cls.fit(X_train, y_train)
y_pred=cls.predict(X_test)
print(accuracy_score(y_test, y_pred))

# 100 % accuracy .>> radias(type of data)>> rbf
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
cls=SVC(kernel='sigmoid') 
cls.fit(X_train, y_train)
y_pred=cls.predict(X_test)
print(accuracy_score(y_test, y_pred))

# sigmoid is also not much good
# Out:
# 0.65

# %%
# how to find which is good >> hyperparameter tuning

# %%
# hyperparameter tuning with svc

# grid search cv
from sklearn.model_selection import GridSearchCV
params={'C': [1,2,3,10,50,100],
        'gamma': [1,0.1,0.2,0.001,0.003],
        'kernel':['linear', 'poly', 'sigmoid', 'rbf'],
        }

grid=GridSearchCV(cls, param_grid=params, cv=5,verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.596 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.596 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.587 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.587 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.609 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.596 total time=  15.6s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.596 total time=  40.1s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.587 total time=  18.7s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.587 total time=  46.3s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.609 total time=  17.7s
# [CV 1/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.574 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# 1.0
